# %% [markdown]
# <a href="https://colab.research.google.com/github/imdeepakvermaa/Python_Practice/blob/main/OOPPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Person:
  def __init__(self,name,country):
    self.name = name
    self.country = country
  def greet(self):
    if self.country == 'india':
      print('Namaste ',self.name)
    else:
      print('Hello ',self.name)

# %%
p = Person('Deepak','India')
p.country
# Out:
# 'India'

# %%
p.greet()
# Out:
# Hello  Deepak

# %%
p.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a6f74d1c7954> in <cell line: 0>()
# ----> 1 p.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %%
p.gender = 'male'

# %%
p.gender
# Out:
# 'male'

# %%
class Person:
  def __init__(self,name,country):
    self.name = name
    self.country = country
  def greet(self):
    if self.country == 'india':
      print('Namaste ',self.name)
    else:
      print('Hello ',self.name)

# %%
p = Person('Deepak','India')
q = p
print(id(p))
print(id(q))
# Out:
# 135726003229200
# 135726003229200

# %%
# Out:
# 135726048955600
