# %%
print("Hello")
# Out:
# Hello

# %%
print("Deepak Verma",2024,29733.50,True)
# Out:
# Deepak Verma 2024 29733.5 True

# %%
print("Deepak Verma",2024,29733.50,True,sep='----->')
# Out:
# Deepak Verma----->2024----->29733.5----->True

# %%
print("Deepak",end='.')
print("Verma")
# Out:
# Deepak.Verma

# %%
type(5)
# Out:
# int

# %%
type(7+5j)
# Out:
# complex

# %%
name = 'deepak Verma'

# %%
print(name)
# Out:
# deepak Verma

# %%
#dynamic typing........

a = 5 #interpreter will understand automatically that the variable is which type

# %%
a = 5 #a is varisable which contain 5 in it.
b = 50
print(a+b)
# Out:
# 55

# %%
a = int(input("Enter number 1: "))
b = int(input("Enter number 2: "))
print("sum of num1 and num2 is : ",a+b)
# Out:
# Enter number 1:  4
# Enter number 2:  5
# sum of num1 and num2 is :  9

# %%
#this is a comment

# %%
#Dynamic typing
a = 5
print(a)
a = "Hey"
print(a)

#static typing
int a = 5
# Out:
# 5
# Hey

# %%
#Dynamic binding 
#similar to dynamic typing

# %%
input()
# Out:
#  Hey i am learning input in python
# 'Hey i am learning input in python'

# %%
input()
# Out:
#  Hey I am learning.
# 'Hey I am learning.'

# %%
input('Enter your unique ID : ')
# Out:
# Enter your unique ID :  imdeepakvermaa
# 'imdeepakvermaa'

# %%
a = input('Enter 1st number : ')
b = input('Enter 2nd number : ')
result = a + b 
#print(result)
print(type(a))
# Out:
# Enter 1st number :  23
# Enter 2nd number :  45
# <class 'str'>

# %%
a = int(input('Enter 1st number : '))
b = int(input('Enter 2nd number : '))
result = a + b 
print(result)
print(type(a))
print(type(b))
# Out:
# Enter 1st number :  45
# Enter 2nd number :  5
# 50
# <class 'int'>
# <class 'int'>

# %%
#type conversion 
#-- Implicit 
#-- Explicit

# %%
a = 0b11000
print(a)
# Out:
# 24
